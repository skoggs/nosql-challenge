# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd
import re

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene":20}
results = establishments.find(query)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('640d4d6e9eab05f7fbc0a54f'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'latitude': None,
# ...

# %%
# Use count_documents to display the number of documents in the result
db.establishments.count_documents(query)
# Out:
# 41

# %%
# Display the first document in the results using pprint
results = establishments.find(query)
pprint(results[0])
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('640d4d6e9eab05f7fbc0a54f'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'latitude': None,
# ...

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(results)

# %%
# Display the number of rows in the DataFrame
index = df.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 41

# %%
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  640d4d6e9eab05f7fbc0a54f   110681                  0
# 1  640d4d6e9eab05f7fbc0a8ce   612039                  0
# 2  640d4d6e9eab05f7fbc0abd8   730933                  0
# 3  640d4d6e9eab05f7fbc0adc8   172735                  0
# 4  640d4d6e9eab05f7fbc0add4   172953                  0
# 5  640d4d6f9eab05f7fbc0b776   512854                  0
# 6  640d4d6f9eab05f7fbc0b997  1537089                  0
# 7  640d4d6f9eab05f7fbc0cec0   155648                  0
# 8  640d4d6f9eab05f7fbc0d306  1012883                  0
# 9  640d4d6f9eab05f7fbc0db18   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
#rv4 = {"LocalAuthorityName": {"$regex":r'\Bondo'},("$or":[{"RaingValue":'4'}, {"RatingValue":5}])}
rv4 = {"LocalAuthorityName": {"$regex":r'\Bondo'}, "RatingValue": '4'}
rv5 = {"LocalAuthorityName": {"$regex":r'\Bondo'}, "RatingValue": '5'}
results1 = establishments.find(rv4)
results2 = establishments.find(rv5)

# %%
# Use count_documents to display the number of documents in the result
#Number of Documents with RatingValue equal to 4 plus equal to 5:
db.establishments.count_documents(rv4)+db.establishments.count_documents(rv5)
# Out:
# 33

# %%
# Display the first document in the results using pprint
pprint(results1[0])
# Out:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('640d4d6f9eab05f7fbc0bf6a'),
#  'geocode': {'latitude': Decimal128('51.369321'),
#              'longitude': Decimal128('0.508551')},
# ...

# %%
# Convert the result to a Pandas DataFrame
#Note that this DataFrame only covers the RatingValue 5 results.
df2 = pd.DataFrame(results2)
df1 = pd.DataFrame(results1)
df3 = pd.concat([df1, df2])

# %%
# Display the number of rows in the DataFrame
index2 = df3.index
number_of_rows2 = len(index2)
print(number_of_rows2)
# Out:
# 33

# %%
# Display the first 10 rows of the DataFrame
df3.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  640d4d6f9eab05f7fbc0bf6a   621707                  0
# 1  640d4d6f9eab05f7fbc0cdda   293783                  0
# 2  640d4d6f9eab05f7fbc107ba   878523                  0
# 3  640d4d6f9eab05f7fbc10e86  1392440                  0
# 0  640d4d6f9eab05f7fbc0c28f  1130836                  0
# 1  640d4d6f9eab05f7fbc0dbdb  1315095                  0
# 2  640d4d6f9eab05f7fbc0dbdc   294474                  0
# 3  640d4d6f9eab05f7fbc0e2e6   294900                  0
# 4  640d4d6f9eab05f7fbc103f3   293756                  0
# 5  640d4d6f9eab05f7fbc107d3   293772                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000002614             Benfleet Motor Yacht Club
# 2             PI/000029844                      Brick Lane Brews
# 3             PI/000037382                         La Nonna lina
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

#latitude = 51.49014200
#longitude = 0.08384000

query = {'$and':[{'geocode.latitude':{'$lt': 51.500142}},
                                        {'geocode.latitude': {'$gt': 51.480142}},
                                        {'geocode.longitude': {'$lt': 0.08484000}},
                                        {'geocode.longitude': {'$gt': 0.08284000}},
                                       {'RatingValue': '5'}]}
sort = [('scores.Hygiene', 1)]
results3 = establishments.find(query).sort(sort).limit(5)

for result in results3:
    pprint(result)
# Out:
# {'AddressLine1': 'East Plumstead Baptist Church Griffin Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'East Plumstead Pre School',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4647.170481326419,
#  'FHRSID': 695318,
#  'LocalAuthorityBusinessID': 'PI/000182731',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 7PZ',
#  'RatingDate': '2021-06-23T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('640d4d6f9eab05f7fbc0ff62'),
#  'geocode': {'latitude': Decimal128('51.4845542907715'),
#              'longitude': Decimal128('0.0836590006947517')},
#  'latitude': None,
# ...

# %%
# Convert result to Pandas DataFrame
result_df = pd.DataFrame(results3)

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query = {'$match': {'scores.Hygiene': 0}}
results = establishments.find(match_query)

# %%
# 2. Groups the matches by Local Authority
group_query = {'$group': {'_id':"$LocalAuthorityName",'count': {'$sum': 1}}}
# 3. Sorts the matches from highest to lowest
sort_values = {'$sort':{'count':-1}}
pipeline = [match_query, group_query, sort_values]

# %%
# Print the number of documents in the result
results = list(establishments.aggregate(pipeline))
print("Number of classifications in result: ", len(results))
# Out:
# Number of classifications in result:  55

# %%
# Print the first 10 results
pprint(results[0:10])
# Out:
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
# This code is sampled from the BuildAPipeline_solved exercise.
result_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_df))
# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# Rows in DataFrame:  55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
